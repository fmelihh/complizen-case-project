# %%
# !uv add requests
# Out:
# Resolved 111 packages in 22ms
# Audited 107 packages in 0.02ms

# %%
import requests

# %%
url = "https://api.fda.gov/device/510k.json?limit=5"

# %%
response = requests.get(url)

# %%
response.headers
# Out:
# {'Date': 'Wed, 21 May 2025 20:32:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Origin': '*', 'Age': '0', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Content-Encoding': 'gzip', 'Content-Security-Policy': "default-src 'none'", 'Etag': 'W/"ac59-aplOQiBgYyg8vRWCZZp6Wxg2WlM"', 'Link': '<https://api.fda.gov/device/510k.json?limit=5&skip=0&search_after=0%3D-91Z45YBRHZBpSx21du8>; rel="next"', 'Strict-Transport-Security': 'max-age=31536000;, max-age=31536000; preload', 'Vary': 'Accept-Encoding, Accept-Encoding', 'Via': 'https/1.1 api-umbrella (ApacheTrafficServer [cMsSf ])', 'X-Api-Umbrella-Request-Id': 'cmui5ttndsd5062s2160', 'X-Cache': 'MISS', 'X-Content-Type-Options': 'nosniff', 'X-Vcap-Request-Id': 'ee6cc131-af78-41b2-4117-55e4583ad8e1', 'X-Xss-Protection': '1; mode=block', 'X-Frame-Options': 'deny'}

# %%
response.headers.get("Link").split(";")[0].replace("<", "").replace(">", "").strip()
# Out:
# 'https://api.fda.gov/device/510k.json?limit=5&skip=0&search_after=0%3D-91Z45YBRHZBpSx21du8'

# %%
if not "":
    print("a")
# Out:
# a

# %%
data = response.json()

# %%
data["meta"]
# Out:
# {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#  'terms': 'https://open.fda.gov/terms/',
#  'license': 'https://open.fda.gov/license/',
#  'last_updated': '2025-05-12',
#  'results': {'skip': 0, 'limit': 5, 'total': 171708}}

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
res = data["results"][4]

# %%
res
# Out:
# {'third_party_flag': 'N',
#  'city': 'CONCORD',
#  'advisory_committee_description': 'Clinical Toxicology',
#  'address_1': '2400 BISSO LN.',
#  'address_2': '',
#  'statement_or_summary': 'Summary',
#  'product_code': 'DIO',
#  'openfda': {'registration_number': ['',
#    '3004847291',
#    '3031823359',
#    '2915274',
#    '1649661',
#    '3008054239',
#    '1063851',
#    '2250051',
#    '2030633',
#    '3005984081',
#    '3023330725',
#    '3030648160',
#    '3024463179',
#    '3003917514',
#    '3008416529',
#    '2060833',
#    '8043323',
#    '3007135420',
#    '3010939897',
#    '1320738',
#    '3007838093',
#    '3012963943',
#    '3016609999',
#    '3013684380',
#    '3005360469',
#    '2951296',
#    '3010220539',
#    '3005333358',
#    '9610529',
#    '3010852191',
#    '3004987297',
#    '2528909',
#    '2020952',
#    '3005174594',
#    '3005345870',
#    '1910144',
#    '2517506',
#    '1827821',
#    '3011522054',
#    '3002642396',
#    '3027519599',
#    '1319681',
#    '3011559327',
#    '3000308930',
#    '3010825766',
#    '1319808',
#    '2244821',
#    '9610126',
#    '3006798115',
#    '1832216',
#    '3008987086',
#    '3007126977',
#    '3016610313',
#    '2247117',
#    '3003610499',
#    '3017904598',
#    '3014730829',
#    '3008517993',
#    '3012234563',
#    '3009585529',
#    '1050155',
#    '3007606081',
#    '2246703',
#    '2030861',
#    '2027969',
#    '3006048451',
#    '3013679502',
#    '2029372',
#    '2432235',
#    '3021186226',
#    '3022137053',
#    '3006198300',
#    '2050010',
#    '3034694973',
#    '3005641941',
#    '2050012',
#    '3009212837',
#    '3010131137',
#    '3003297763',
#    '3006305917',
#    '2087033',
#    '3003795116',
#    '3009238284',
#    '3004175381',
#    '2249781',
#    '3009414546',
#    '3002806944',
#    '3008852306',
#    '3012073813',
#    '3023322455',
#    '3016637761',
#    '3025672',
#    '3004635103',
#    '3013077867',
#    '1220972',
#    '2000007960',
#    '3012725363',
#    '3021841051',
#    '3022474803',
#    '1036362',
#    '2031229',
#    '3010800486',
#    '2025099',
#    '3010934853'],
#   'fei_number': ['',
#    '3004847291',
#    '3031823359',
#    '2915274',
#    '3000719950',
#    '3008054239',
#    '2250051',
#    '3005984081',
#    '3023330725',
#    '1000125596',
#    '3030648160',
#    '3024463179',
#    '3003917514',
#    '3008416529',
#    '3007135420',
#    '3010939897',
#    '3007838093',
#    '3012963943',
#    '3016609999',
#    '3013684380',
#    '3010220539',
#    '3005333358',
#    '3005670738',
#    '3010852191',
#    '3004987297',
#    '2528909',
#    '2020952',
#    '3005174594',
#    '3005345870',
#    '1910144',
#    '2517506',
#    '1827821',
#    '3011522054',
#    '3002642396',
#    '3000210620',
#    '3027519599',
#    '3011559327',
#    '3000308930',
#    '3010825766',
#    '1000136573',
#    '2244821',
#    '3006798115',
#    '1832216',
#    '3008987086',
#    '3007126977',
#    '3002806559',
#    '3016610313',
#    '3003610499',
#    '3017904598',
#    '3000215862',
#    '3014730829',
#    '3008517993',
#    '3012234563',
#    '3009585529',
#    '3003102569',
#    '1050155',
#    '3007606081',
#    '1000306617',
#    '3010934853',
#    '2246703',
#    '1000442352',
#    '3003204823',
#    '3006048451',
#    '3013679502',
#    '2432235',
#    '3021186226',
#    '3022137053',
#    '1000221312',
#    '3006198300',
#    '2050010',
#    '3034694973',
#    '3005641941',
#    '3001451797',
#    '3001452245',
#    '2050012',
#    '3009212837',
#    '3010131137',
#    '3003297763',
#    '3006305917',
#    '3003795116',
#    '3007981058',
#    '3009238284',
#    '3004175381',
#    '1000305841',
#    '1000122204',
#    '3009414546',
#    '3002806944',
#    '3000718556',
#    '3008852306',
#    '3012073813',
#    '3023322455',
#    '3016637761',
#    '3004635103',
#    '3013077867',
#    '1220972',
#    '2000007960',
#    '3012725363',
#    '3021841051',
#    '3022474803',
#    '1000126037',
#    '3006078362',
#    '1036362',
#    '3010800486',
#    '3002806560'],
#   'device_name': 'Enzyme Immunoassay, Cocaine And Cocaine Metabolites',
#   'medical_specialty_description': 'Clinical Toxicology',
#   'regulation_number': '862.3250',
#   'device_class': '2'},
#  'zip_code': '94520',
#  'applicant': 'MICROGENICS CORP.',
#  'decision_date': '1994-06-02',
#  'decision_code': 'SESE',
#  'country_code': 'US',
#  'device_name': 'CEDIA DAU COCAINE ASSAY',
#  'advisory_committee': 'TX',
#  'contact': 'Patricia  Klimley',
#  'expedited_review_flag': '',
#  'k_number': 'K941310',
#  'state': 'CA',
#  'date_received': '1994-03-14',
#  'review_advisory_committee': 'TX',
#  'postal_code': '94520',
#  'decision_description': 'Substantially Equivalent',
#  'clearance_type': 'Traditional'}

# %%
res
# Out:
# {'third_party_flag': 'N',
#  'city': 'CONCORD',
#  'advisory_committee_description': 'Clinical Toxicology',
#  'address_1': '2400 BISSO LN.',
#  'address_2': '',
#  'statement_or_summary': 'Summary',
#  'product_code': 'DIO',
#  'openfda': {'registration_number': ['',
#    '3004847291',
#    '3031823359',
#    '2915274',
#    '1649661',
#    '3008054239',
#    '1063851',
#    '2250051',
#    '2030633',
#    '3005984081',
#    '3023330725',
#    '3030648160',
#    '3024463179',
#    '3003917514',
#    '3008416529',
#    '2060833',
#    '8043323',
#    '3007135420',
#    '3010939897',
#    '1320738',
#    '3007838093',
#    '3012963943',
#    '3016609999',
#    '3013684380',
#    '3005360469',
#    '2951296',
#    '3010220539',
#    '3005333358',
#    '9610529',
#    '3010852191',
#    '3004987297',
#    '2528909',
#    '2020952',
#    '3005174594',
#    '3005345870',
#    '1910144',
#    '2517506',
#    '1827821',
#    '3011522054',
#    '3002642396',
#    '3027519599',
#    '1319681',
#    '3011559327',
#    '3000308930',
#    '3010825766',
#    '1319808',
#    '2244821',
#    '9610126',
#    '3006798115',
#    '1832216',
#    '3008987086',
#    '3007126977',
#    '3016610313',
#    '2247117',
#    '3003610499',
#    '3017904598',
#    '3014730829',
#    '3008517993',
#    '3012234563',
#    '3009585529',
#    '1050155',
#    '3007606081',
#    '2246703',
#    '2030861',
#    '2027969',
#    '3006048451',
#    '3013679502',
#    '2029372',
#    '2432235',
#    '3021186226',
#    '3022137053',
#    '3006198300',
#    '2050010',
#    '3034694973',
#    '3005641941',
#    '2050012',
#    '3009212837',
#    '3010131137',
#    '3003297763',
#    '3006305917',
#    '2087033',
#    '3003795116',
#    '3009238284',
#    '3004175381',
#    '2249781',
#    '3009414546',
#    '3002806944',
#    '3008852306',
#    '3012073813',
#    '3023322455',
#    '3016637761',
#    '3025672',
#    '3004635103',
#    '3013077867',
#    '1220972',
#    '2000007960',
#    '3012725363',
#    '3021841051',
#    '3022474803',
#    '1036362',
#    '2031229',
#    '3010800486',
#    '2025099',
#    '3010934853'],
#   'fei_number': ['',
#    '3004847291',
#    '3031823359',
#    '2915274',
#    '3000719950',
#    '3008054239',
#    '2250051',
#    '3005984081',
#    '3023330725',
#    '1000125596',
#    '3030648160',
#    '3024463179',
#    '3003917514',
#    '3008416529',
#    '3007135420',
#    '3010939897',
#    '3007838093',
#    '3012963943',
#    '3016609999',
#    '3013684380',
#    '3010220539',
#    '3005333358',
#    '3005670738',
#    '3010852191',
#    '3004987297',
#    '2528909',
#    '2020952',
#    '3005174594',
#    '3005345870',
#    '1910144',
#    '2517506',
#    '1827821',
#    '3011522054',
#    '3002642396',
#    '3000210620',
#    '3027519599',
#    '3011559327',
#    '3000308930',
#    '3010825766',
#    '1000136573',
#    '2244821',
#    '3006798115',
#    '1832216',
#    '3008987086',
#    '3007126977',
#    '3002806559',
#    '3016610313',
#    '3003610499',
#    '3017904598',
#    '3000215862',
#    '3014730829',
#    '3008517993',
#    '3012234563',
#    '3009585529',
#    '3003102569',
#    '1050155',
#    '3007606081',
#    '1000306617',
#    '3010934853',
#    '2246703',
#    '1000442352',
#    '3003204823',
#    '3006048451',
#    '3013679502',
#    '2432235',
#    '3021186226',
#    '3022137053',
#    '1000221312',
#    '3006198300',
#    '2050010',
#    '3034694973',
#    '3005641941',
#    '3001451797',
#    '3001452245',
#    '2050012',
#    '3009212837',
#    '3010131137',
#    '3003297763',
#    '3006305917',
#    '3003795116',
#    '3007981058',
#    '3009238284',
#    '3004175381',
#    '1000305841',
#    '1000122204',
#    '3009414546',
#    '3002806944',
#    '3000718556',
#    '3008852306',
#    '3012073813',
#    '3023322455',
#    '3016637761',
#    '3004635103',
#    '3013077867',
#    '1220972',
#    '2000007960',
#    '3012725363',
#    '3021841051',
#    '3022474803',
#    '1000126037',
#    '3006078362',
#    '1036362',
#    '3010800486',
#    '3002806560'],
#   'device_name': 'Enzyme Immunoassay, Cocaine And Cocaine Metabolites',
#   'medical_specialty_description': 'Clinical Toxicology',
#   'regulation_number': '862.3250',
#   'device_class': '2'},
#  'zip_code': '94520',
#  'applicant': 'MICROGENICS CORP.',
#  'decision_date': '1994-06-02',
#  'decision_code': 'SESE',
#  'country_code': 'US',
#  'device_name': 'CEDIA DAU COCAINE ASSAY',
#  'advisory_committee': 'TX',
#  'contact': 'Patricia  Klimley',
#  'expedited_review_flag': '',
#  'k_number': 'K941310',
#  'state': 'CA',
#  'date_received': '1994-03-14',
#  'review_advisory_committee': 'TX',
#  'postal_code': '94520',
#  'decision_description': 'Substantially Equivalent',
#  'clearance_type': 'Traditional'}

# %%
url = "https://download.open.fda.gov/device/510k/device-510k-0001-of-0001.json.zip"

# %%
requests.get()

# %%
import io
import json
import zipfile

response = requests.get(url)

# %%
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    print(zip_ref.namelist())
    
    json_filename = zip_ref.namelist()[0]
    
    with zip_ref.open(json_filename) as json_file:
        data = json.load(json_file)

print(type(data)) 
print(data.keys())
# Out:
# ['device-510k-0001-of-0001.json']
# <class 'dict'>
# dict_keys(['meta', 'results'])

# %%
len(data["results"])
# Out:
# 171708

# %%
data["results"][0]
# Out:
# {'third_party_flag': 'N',
#  'city': 'NORWOOD',
#  'advisory_committee_description': 'General, Plastic Surgery',
#  'address_1': '57 PROVIDENCE HWY.',
#  'address_2': '',
#  'statement_or_summary': 'Statement',
#  'product_code': 'GFG',
#  'openfda': {'registration_number': ['3007344102',
#    '',
#    '3010470577',
#    '1058584',
#    '3023852420',
#    '9613350',
#    '3009971621',
#    '1320894',
#    '1828464',
#    '3006017180',
#    '1221485',
#    '1833986',
#    '3023155873',
#    '3007125392',
#    '3009582259',
#    '3004776227',
#    '1828288',
#    '3015399803',
#    '3010045785',
#    '3003431869',
#    '2245304',
#    '3009417901',
#    '1000517406',
#    '3010536692',
#    '3014199274',
#    '3014662844',
#    '3003604053',
#    '3034676720',
#    '3012130008',
#    '3010388970',
#    '3032391',
#    '3000931034',
#    '3007993775',
#    '9616944',
#    '3015882686',
#    '2031917',
#    '2936485',
#    '1825034',
#    '3008114965',
#    '1835251',
#    '1000461041',
#    '3012217062',
#    '3011685188',
#    '3009540749',
#    '3002719998',
#    '1526534',
#    '3015212339',
#    '3010363503',
#    '3009923627',
#    '3007208013',
#    '3011943495',
#    '3006272282',
#    '3003477135',
#    '3011569539',
#    '3006561161',
#    '3005061536',
#    '3015967359',
#    '3010462278',
#    '3008812560',
#    '1646747',
#    '3008902714',
#    '1220477',
#    '3006563559',
#    '3019261113',
#    '2029275',
#    '2081135',
#    '1221934',
#    '1043653',
#    '1017294',
#    '3006128100',
#    '3010155648',
#    '3015200759',
#    '1649390',
#    '1043534',
#    '3010287737',
#    '3024788684',
#    '3004464325',
#    '3006460162',
#    '8043971',
#    '3009973699',
#    '3008744062',
#    '3010173425',
#    '8040278',
#    '3007366790',
#    '3010667733',
#    '9616696',
#    '3001239363',
#    '1219602',
#    '3004889950',
#    '3023265483',
#    '3005067367',
#    '1020279',
#    '3017860875',
#    '3012358417',
#    '8043792',
#    '3025141',
#    '3000270450',
#    '3004983210'],
#   'fei_number': ['3007344102',
#    '1000219637',
#    '',
#    '3010470577',
#    '1000160162',
#    '3023852420',
#    '3009971621',
#    '1828464',
#    '1000272060',
#    '3006017180',
#    '3000205591',
#    '1221485',
#    '3023155873',
#    '3007125392',
#    '3009582259',
#    '3004776227',
#    '1828288',
#    '3015399803',
#    '3010045785',
#    '3003431869',
#    '2245304',
#    '1000306431',
#    '3009417901',
#    '1000517406',
#    '3010536692',
#    '3014199274',
#    '3014662844',
#    '3003604053',
#    '3034676720',
#    '3012130008',
#    '3010388970',
#    '3000931034',
#    '3007993775',
#    '1000139987',
#    '3015882686',
#    '2936485',
#    '1825034',
#    '3008114965',
#    '1000461041',
#    '3012217062',
#    '3011685188',
#    '3009540749',
#    '3000718467',
#    '1000125930',
#    '3002719998',
#    '1526534',
#    '3015212339',
#    '3010363503',
#    '3009923627',
#    '3007208013',
#    '3011943495',
#    '3006272282',
#    '3003477135',
#    '3011569539',
#    '3001451571',
#    '3006561161',
#    '3005061536',
#    '3015967359',
#    '3003164255',
#    '3003414678',
#    '3010462278',
#    '3008812560',
#    '3008902714',
#    '3002807036',
#    '1220477',
#    '3006563559',
#    '3019261113',
#    '3007282753',
#    '2081135',
#    '1221934',
#    '1043653',
#    '1017294',
#    '3006128100',
#    '3010155648',
#    '3015200759',
#    '1043534',
#    '3010287737',
#    '3002299608',
#    '3024788684',
#    '3004464325',
#    '3006460162',
#    '3009973699',
#    '3008744062',
#    '3546',
#    '3010667733',
#    '3001239363',
#    '1219602',
#    '3004889950',
#    '3023265483',
#    '1020279',
#    '3017860875',
#    '3012358417',
#    '3005233524',
#    '3002808269',
#    '3002929183',
#    '3004216008',
#    '3000270450',
#    '3004983210'],
#   'device_name': 'Bit, Surgical',
#   'medical_specialty_description': 'General, Plastic Surgery',
#   'regulation_number': '878.4820',
#   'device_class': '1'},
#  'zip_code': '02062',
#  'applicant': 'MITEK SURGICAL PRODUCTS, INC.',
#  'decision_date': '1994-04-07',
#  'decision_code': 'SESE',
#  'country_code': 'US',
#  'device_name': 'MITEK MODULAR DRILL BIT',
#  'advisory_committee': 'SU',
#  'contact': 'Robert  Zoletti',
#  'expedited_review_flag': '',
#  'k_number': 'K935225',
#  'state': 'MA',
#  'date_received': '1993-11-01',
#  'review_advisory_committee': 'SU',
#  'postal_code': '02062',
#  'decision_description': 'Substantially Equivalent',
#  'clearance_type': 'Traditional'}
